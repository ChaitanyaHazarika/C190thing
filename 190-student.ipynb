# %%
print("Name : idk ")
# Out:
# Name : idk

# %%
#import the libraries
import pandas as pd
from matplotlib import pyplot as plt

bmi_df= pd.read_csv('bmi.csv')
bmi_df

#Task 1
#Read the bmi.csv
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0           177            0      129            110             46      130  \
# 1           445            0      180             78             63       14
# 2           673            3      123            100             35      240
# 3           125            1       88             30             42       99
# 4           120            0      162             76             56      100
# ..          ...          ...      ...            ...            ...      ...
# 763         426            0       94              0              0        0
# 764         706           10      115              0              0        0
# 765         371            0      118             64             23       89
# 766           9            8      125             96              0        0
# 767         145            0      102             75             23        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    67.1                     0.319   26        1
# 1    59.4                     2.420   25        1
# 2    57.3                     0.880   22        0
# 3    55.0                     0.496   26        1
# 4    53.2                     0.759   25        1
# ..    ...                       ...  ...      ...
# 763   0.0                     0.256   25        0
# 764   0.0                     0.261   30        1
# 765   0.0                     1.731   21        0
# 766   0.0                     0.232   54        1
# 767   0.0                     0.572   21        0
#
# [768 rows x 10 columns]

# %%
#Task 2
#Data is sorted in descending order in accordance with BMI value
#Find the top 5 age group where the BMI value is the highest, and plot a bar graph out of it

t5=bmi_df.head(5)
name= t5['Age']
number= t5["BMI"]
plt.xlabel("Age")
plt.xticks(rotation= 'vertical')
plt.ylabel("BMI")

label= name
value= number
print(label)
print(value)
plt.bar(label, value, width= 0.5, color=("Blue", "Green", "Black", "Pink", "Red"))
# Out:
# 0    26
# 1    25
# 2    22
# 3    26
# 4    25
# Name: Age, dtype: int64
# 0    67.1
# 1    59.4
# 2    57.3
# 3    55.0
# 4    53.2
# Name: BMI, dtype: float64
# <BarContainer object of 5 artists>

# %%
#Task 3
#Read blood_pressure.csv
bp_df= pd.read_csv('blood_pressure.csv')
bp_df
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0           347            3      116              0              0        0  \
# 1           494            3       80              0              0        0
# 2           222            7      119              0              0        0
# 3            81            2       74              0              0        0
# 4            78            0      131              0              0        0
# ..          ...          ...      ...            ...            ...      ...
# 763         549            4      189            110             31        0
# 764          43            9      171            110             24      240
# 765         177            0      129            110             46      130
# 766         691           13      158            114              0        0
# 767         106            1       96            122              0        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    23.5                     0.187   23        0
# 1     0.0                     0.174   22        0
# 2    25.2                     0.209   37        0
# 3     0.0                     0.102   22        0
# 4    43.2                     0.270   26        1
# ..    ...                       ...  ...      ...
# 763  28.5                     0.680   37        0
# 764  45.4                     0.721   54        1
# 765  67.1                     0.319   26        1
# 766  42.3                     0.257   44        1
# 767  22.4                     0.207   27        0
#
# [768 rows x 10 columns]

# %%
#Task 4
#Data is sorted in ascending order in accordance with Blood Pressure
#Find the top 5 age group where the BloodPressure value is the highest, and plot a bar graph out of it
bp5= bp_df.tail(5)
bp5

name= bp5["Age"]
number= bp5["BloodPressure"]
plt.xlabel("Age")
plt.xticks(rotation= 'vertical')

plt.ylabel("Blood Pressure")
label= name
value= number
plt.bar(label, value, width= 0.5, color=("Blue", "Green", "Black", "Pink", "Red"))
# Out:
# <BarContainer object of 5 artists>

# %%
#Task 5
#Read the insulin.csv

insulin_df= pd.read_csv('insulin.csv')
insulin_df
# Out:
#      Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin
# 0            13            1      189             60             23      846  \
# 1           228            4      197             70             39      744
# 2           247            0      165             90             33      680
# 3           584            8      124             76             24      600
# 4           409            1      172             68             49      579
# ..          ...          ...      ...            ...            ...      ...
# 763         218            5       85             74             22        0
# 764           5            5      116             74              0        0
# 765         598            1      173             74              0        0
# 766         761            9      170             74             31        0
# 767         266            0      138              0              0        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    30.1                     0.398   59        1
# 1    36.7                     2.329   31        0
# 2    52.3                     0.427   23        0
# 3    28.7                     0.687   52        1
# 4    42.4                     0.702   28        1
# ..    ...                       ...  ...      ...
# 763  29.0                     1.224   32        1
# 764  25.6                     0.201   30        0
# 765  36.8                     0.088   38        1
# 766  44.0                     0.403   43        1
# 767  36.3                     0.933   25        1
#
# [768 rows x 10 columns]

# %%
#Task 6
#Data is sorted in descending order in accordance with Insulin value
#Find out what will be the Glucose and BMI value when the Insulin is highest

top1= insulin_df.head(1)


print("When is insulin is the highest, glucose is :" ,top1["Glucose"])
print("\n When is insulin is the highest, BMI is :" ,top1["BMI"])
# Out:
# When is insulin is the highest, glucose is : 0    189
# Name: Glucose, dtype: int64
#
#  When is insulin is the highest, BMI is : 0    30.1
# Name: BMI, dtype: float64
